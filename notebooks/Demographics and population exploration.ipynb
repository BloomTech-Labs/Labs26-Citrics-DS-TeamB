# %%
import pandas as pd
import numpy as np 

# Load in the data 
df1 = pd.read_csv(r"C:\Users\Z Dubs\lambda\labs_week1\pop_data\census_demodata_2010.csv", encoding='utf-8')
df2 = pd.read_csv(r"C:\Users\Z Dubs\lambda\labs_week1\pop_data\census_demodata_2011.csv", encoding='utf-8')
df3 = pd.read_csv(r"C:\Users\Z Dubs\lambda\labs_week1\pop_data\census_demodata_2012.csv", encoding='utf-8')
df4 = pd.read_csv(r"C:\Users\Z Dubs\lambda\labs_week1\pop_data\census_demodata_2013.csv", encoding='utf-8')
df5 = pd.read_csv(r"C:\Users\Z Dubs\lambda\labs_week1\pop_data\census_demodata_2014.csv", encoding='utf-8')
df6 = pd.read_csv(r"C:\Users\Z Dubs\lambda\labs_week1\pop_data\census_demodata_2015.csv", encoding='utf-8')
df7 = pd.read_csv(r"C:\Users\Z Dubs\lambda\labs_week1\pop_data\census_demodata_2016.csv", encoding='utf-8')
df8 = pd.read_csv(r"C:\Users\Z Dubs\lambda\labs_week1\pop_data\census_demodata_2017.csv", encoding='utf-8')
df9 = pd.read_csv(r"C:\Users\Z Dubs\lambda\labs_week1\pop_data\census_demodata_2018.csv", encoding='utf-8')

# %%
df2
# Out:
#                GEO_ID                               NAME  \
# 0                  id               Geographic Area Name
# 1    1600000US1759000              Peoria city, Illinois
# 2    1600000US1765000            Rockford city, Illinois
# 3    1600000US1768003       Schaumburg village, Illinois
# 4    1600000US1770122           Skokie village, Illinois
# ..                ...                                ...
# 558  1600000US1738570              Joliet city, Illinois
# 559  1600000US1751622          Naperville city, Illinois
# 560  1600000US1757225         Palatine village, Illinois
# 561  1600000US7206593   Bayamón zona urbana, Puerto Rico
# 562  1600000US7252431  Mayagüez zona urbana, Puerto Rico
#
#                         S0101_C01_001E  \
# 0    Total!!Estimate!!Total population
# 1                               113715
# 2                               152485
# 3                                74198
# 4                                65070
# ...

# %%
# View all columns and increase column width for visibility
pd.set_option('display.max_columns', None)
pd.options.display.max_colwidth = 100

# %%
# Include only pertinent data into the df 
clean_df1 = df1[['GEO_ID','NAME','S0101_C01_001E','S0101_C02_001E','S0101_C03_001E','S0101_C01_002E','S0101_C01_003E','S0101_C01_004E','S0101_C01_005E','S0101_C01_006E','S0101_C01_007E','S0101_C01_008E','S0101_C01_009E','S0101_C01_010E','S0101_C01_011E','S0101_C01_012E','S0101_C01_013E','S0101_C01_014E','S0101_C01_015E','S0101_C01_016E','S0101_C01_017E','S0101_C01_018E','S0101_C01_019E']]
clean_df2 = df2[['GEO_ID','NAME','S0101_C01_001E','S0101_C02_001E','S0101_C03_001E','S0101_C01_002E','S0101_C01_003E','S0101_C01_004E','S0101_C01_005E','S0101_C01_006E','S0101_C01_007E','S0101_C01_008E','S0101_C01_009E','S0101_C01_010E','S0101_C01_011E','S0101_C01_012E','S0101_C01_013E','S0101_C01_014E','S0101_C01_015E','S0101_C01_016E','S0101_C01_017E','S0101_C01_018E','S0101_C01_019E']]
clean_df3 = df3[['GEO_ID','NAME','S0101_C01_001E','S0101_C02_001E','S0101_C03_001E','S0101_C01_002E','S0101_C01_003E','S0101_C01_004E','S0101_C01_005E','S0101_C01_006E','S0101_C01_007E','S0101_C01_008E','S0101_C01_009E','S0101_C01_010E','S0101_C01_011E','S0101_C01_012E','S0101_C01_013E','S0101_C01_014E','S0101_C01_015E','S0101_C01_016E','S0101_C01_017E','S0101_C01_018E','S0101_C01_019E']]
clean_df4 = df4[['GEO_ID','NAME','S0101_C01_001E','S0101_C02_001E','S0101_C03_001E','S0101_C01_002E','S0101_C01_003E','S0101_C01_004E','S0101_C01_005E','S0101_C01_006E','S0101_C01_007E','S0101_C01_008E','S0101_C01_009E','S0101_C01_010E','S0101_C01_011E','S0101_C01_012E','S0101_C01_013E','S0101_C01_014E','S0101_C01_015E','S0101_C01_016E','S0101_C01_017E','S0101_C01_018E','S0101_C01_019E']]
clean_df5 = df5[['GEO_ID','NAME','S0101_C01_001E','S0101_C02_001E','S0101_C03_001E','S0101_C01_002E','S0101_C01_003E','S0101_C01_004E','S0101_C01_005E','S0101_C01_006E','S0101_C01_007E','S0101_C01_008E','S0101_C01_009E','S0101_C01_010E','S0101_C01_011E','S0101_C01_012E','S0101_C01_013E','S0101_C01_014E','S0101_C01_015E','S0101_C01_016E','S0101_C01_017E','S0101_C01_018E','S0101_C01_019E']]
clean_df6 = df6[['GEO_ID','NAME','S0101_C01_001E','S0101_C02_001E','S0101_C03_001E','S0101_C01_002E','S0101_C01_003E','S0101_C01_004E','S0101_C01_005E','S0101_C01_006E','S0101_C01_007E','S0101_C01_008E','S0101_C01_009E','S0101_C01_010E','S0101_C01_011E','S0101_C01_012E','S0101_C01_013E','S0101_C01_014E','S0101_C01_015E','S0101_C01_016E','S0101_C01_017E','S0101_C01_018E','S0101_C01_019E']]
clean_df7 = df7[['GEO_ID','NAME','S0101_C01_001E','S0101_C02_001E','S0101_C03_001E','S0101_C01_002E','S0101_C01_003E','S0101_C01_004E','S0101_C01_005E','S0101_C01_006E','S0101_C01_007E','S0101_C01_008E','S0101_C01_009E','S0101_C01_010E','S0101_C01_011E','S0101_C01_012E','S0101_C01_013E','S0101_C01_014E','S0101_C01_015E','S0101_C01_016E','S0101_C01_017E','S0101_C01_018E','S0101_C01_019E']]
clean_df8 = df8[['GEO_ID','NAME','S0101_C01_001E','S0101_C02_001E','S0101_C03_001E','S0101_C01_002E','S0101_C01_003E','S0101_C01_004E','S0101_C01_005E','S0101_C01_006E','S0101_C01_007E','S0101_C01_008E','S0101_C01_009E','S0101_C01_010E','S0101_C01_011E','S0101_C01_012E','S0101_C01_013E','S0101_C01_014E','S0101_C01_015E','S0101_C01_016E','S0101_C01_017E','S0101_C01_018E','S0101_C01_019E']]
clean_df9 = df9[['GEO_ID','NAME','S0101_C01_001E','S0101_C03_001E','S0101_C05_001E','S0101_C01_002E','S0101_C01_003E','S0101_C01_004E','S0101_C01_005E','S0101_C01_006E','S0101_C01_007E','S0101_C01_008E','S0101_C01_009E','S0101_C01_010E','S0101_C01_011E','S0101_C01_012E','S0101_C01_013E','S0101_C01_014E','S0101_C01_015E','S0101_C01_016E','S0101_C01_017E','S0101_C01_018E','S0101_C01_019E']]

# %%
# Re-name and lower all column names for readability/useability
clean_df1.columns = ['geo_id', 'city', 'total_pop', 'male_pop', 'female_pop', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79', 'age80-84', 'age>85']
clean_df2.columns = ['geo_id', 'city', 'total_pop', 'male_pop', 'female_pop', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79', 'age80-84', 'age>85']
clean_df3.columns = ['geo_id', 'city', 'total_pop', 'male_pop', 'female_pop', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79', 'age80-84', 'age>85']
clean_df4.columns = ['geo_id', 'city', 'total_pop', 'male_pop', 'female_pop', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79', 'age80-84', 'age>85']
clean_df5.columns = ['geo_id', 'city', 'total_pop', 'male_pop', 'female_pop', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79', 'age80-84', 'age>85']
clean_df6.columns = ['geo_id', 'city', 'total_pop', 'male_pop', 'female_pop', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79', 'age80-84', 'age>85']
clean_df7.columns = ['geo_id', 'city', 'total_pop', 'male_pop', 'female_pop', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79', 'age80-84', 'age>85']
clean_df8.columns = ['geo_id', 'city', 'total_pop', 'male_pop', 'female_pop', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79', 'age80-84', 'age>85']
clean_df9.columns = ['geo_id', 'city', 'total_pop', 'male_pop', 'female_pop', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79', 'age80-84', 'age>85']

# %%
# Drop the first row containing redundant information
clean_df1 = clean_df1.iloc[1:]
clean_df2 = clean_df2.iloc[1:]
clean_df3 = clean_df3.iloc[1:]
clean_df4 = clean_df4.iloc[1:]
clean_df5 = clean_df5.iloc[1:]
clean_df6 = clean_df6.iloc[1:]
clean_df7 = clean_df7.iloc[1:]
clean_df8 = clean_df8.iloc[1:]
clean_df9 = clean_df9.iloc[1:]

# %%
# Convert ambiguous data to NaN's
clean_df5 = clean_df5.replace('N', np.nan)
clean_df6 = clean_df6.replace('N', np.nan)
clean_df7 = clean_df7.replace('N', np.nan)
clean_df8 = clean_df8.replace('N', np.nan)
clean_df9 = clean_df9.replace('N', np.nan)

# %%
# Drops rows with NaN's from dfs
clean_df5 = clean_df5.dropna()
clean_df6 = clean_df5.dropna()
clean_df7 = clean_df5.dropna()
clean_df8 = clean_df5.dropna()
clean_df9 = clean_df5.dropna()

# %%
# Lets take only the cities over 50k population
cities_df1 = clean_df1[clean_df1['total_pop'].astype(int)>=50000]
cities_df2 = clean_df2[clean_df2['total_pop'].astype(int)>=50000]
cities_df3 = clean_df3[clean_df3['total_pop'].astype(int)>=50000]
cities_df4 = clean_df4[clean_df4['total_pop'].astype(int)>=50000]
cities_df5 = clean_df5[clean_df5['total_pop'].astype(int)>=50000]
cities_df6 = clean_df6[clean_df6['total_pop'].astype(int)>=50000]
cities_df7 = clean_df7[clean_df7['total_pop'].astype(int)>=50000]
cities_df8 = clean_df8[clean_df8['total_pop'].astype(int)>=50000]
cities_df9 = clean_df9[clean_df9['total_pop'].astype(int)>=50000]

# %%
# Only include cities from og 50 states
cities_df1 = cities_df1[~cities_df1.city.str.contains("Puerto Rico")]
cities_df2 = cities_df2[~cities_df2.city.str.contains("Puerto Rico")]
cities_df3 = cities_df3[~cities_df3.city.str.contains("Puerto Rico")]
cities_df4 = cities_df4[~cities_df4.city.str.contains("Puerto Rico")]
cities_df5 = cities_df5[~cities_df5.city.str.contains("Puerto Rico")]
cities_df6 = cities_df6[~cities_df6.city.str.contains("Puerto Rico")]
cities_df7 = cities_df7[~cities_df7.city.str.contains("Puerto Rico")]
cities_df8 = cities_df8[~cities_df8.city.str.contains("Puerto Rico")]
cities_df9 = cities_df9[~cities_df9.city.str.contains("Puerto Rico")]

# cities_df9

# %%
# Feature engineer the age demographics
# Have to convert from object type to float so new column 
# sums values instead of appending them 

# Under 20
cities_df1['age_under_20_2010'] = cities_df1['age<5'].astype(float) + cities_df1['age5-9'].astype(float) + cities_df1['age10-14'].astype(float) + cities_df1['age15-19'].astype(float)
cities_df2['age_under_20_2011'] = cities_df2['age<5'].astype(float) + cities_df2['age5-9'].astype(float) + cities_df2['age10-14'].astype(float) + cities_df2['age15-19'].astype(float)
cities_df3['age_under_20_2012'] = cities_df3['age<5'].astype(float) + cities_df3['age5-9'].astype(float) + cities_df3['age10-14'].astype(float) + cities_df3['age15-19'].astype(float)
cities_df4['age_under_20_2013'] = cities_df4['age<5'].astype(float) + cities_df4['age5-9'].astype(float) + cities_df4['age10-14'].astype(float) + cities_df4['age15-19'].astype(float)
cities_df5['age_under_20_2014'] = cities_df5['age<5'].astype(float) + cities_df5['age5-9'].astype(float) + cities_df5['age10-14'].astype(float) + cities_df5['age15-19'].astype(float)
cities_df6['age_under_20_2015'] = cities_df6['age<5'].astype(float) + cities_df6['age5-9'].astype(float) + cities_df6['age10-14'].astype(float) + cities_df6['age15-19'].astype(float)
cities_df7['age_under_20_2016'] = cities_df7['age<5'].astype(float) + cities_df7['age5-9'].astype(float) + cities_df7['age10-14'].astype(float) + cities_df7['age15-19'].astype(float)
cities_df8['age_under_20_2017'] = cities_df8['age<5'].astype(float) + cities_df8['age5-9'].astype(float) + cities_df8['age10-14'].astype(float) + cities_df8['age15-19'].astype(float)
cities_df9['age_under_20_2018'] = cities_df9['age<5'].astype(float) + cities_df9['age5-9'].astype(float) + cities_df9['age10-14'].astype(float) + cities_df9['age15-19'].astype(float)
# 20 - 29
cities_df1['age_21-29_2010'] = cities_df1['age20-24'].astype(float) + cities_df1['age25-29'].astype(float)
cities_df2['age_21-29_2011'] = cities_df2['age20-24'].astype(float) + cities_df2['age25-29'].astype(float)
cities_df3['age_21-29_2012'] = cities_df3['age20-24'].astype(float) + cities_df3['age25-29'].astype(float)
cities_df4['age_21-29_2013'] = cities_df4['age20-24'].astype(float) + cities_df4['age25-29'].astype(float)
cities_df5['age_21-29_2014'] = cities_df5['age20-24'].astype(float) + cities_df5['age25-29'].astype(float)
cities_df6['age_21-29_2015'] = cities_df6['age20-24'].astype(float) + cities_df6['age25-29'].astype(float)
cities_df7['age_21-29_2016'] = cities_df7['age20-24'].astype(float) + cities_df7['age25-29'].astype(float)
cities_df8['age_21-29_2017'] = cities_df8['age20-24'].astype(float) + cities_df8['age25-29'].astype(float)
cities_df9['age_21-29_2018'] = cities_df9['age20-24'].astype(float) + cities_df9['age25-29'].astype(float)
# 30 - 39
cities_df1['age_30-39_2010'] = cities_df1['age30-34'].astype(float) + cities_df1['age35-39'].astype(float)
cities_df2['age_30-39_2011'] = cities_df2['age30-34'].astype(float) + cities_df2['age35-39'].astype(float)
cities_df3['age_30-39_2012'] = cities_df3['age30-34'].astype(float) + cities_df3['age35-39'].astype(float)
cities_df4['age_30-39_2013'] = cities_df4['age30-34'].astype(float) + cities_df4['age35-39'].astype(float)
cities_df5['age_30-39_2014'] = cities_df5['age30-34'].astype(float) + cities_df5['age35-39'].astype(float)
cities_df6['age_30-39_2015'] = cities_df6['age30-34'].astype(float) + cities_df6['age35-39'].astype(float)
cities_df7['age_30-39_2016'] = cities_df7['age30-34'].astype(float) + cities_df7['age35-39'].astype(float)
cities_df8['age_30-39_2017'] = cities_df8['age30-34'].astype(float) + cities_df8['age35-39'].astype(float)
cities_df9['age_30-39_2018'] = cities_df9['age30-34'].astype(float) + cities_df9['age35-39'].astype(float)
# 40 - 49
cities_df1['age_40-49_2010'] = cities_df1['age40-44'].astype(float) + cities_df1['age45-49'].astype(float)
cities_df2['age_40-49_2011'] = cities_df2['age40-44'].astype(float) + cities_df2['age45-49'].astype(float)
cities_df3['age_40-49_2012'] = cities_df3['age40-44'].astype(float) + cities_df3['age45-49'].astype(float)
cities_df4['age_40-49_2013'] = cities_df4['age40-44'].astype(float) + cities_df4['age45-49'].astype(float)
cities_df5['age_40-49_2014'] = cities_df5['age40-44'].astype(float) + cities_df5['age45-49'].astype(float)
cities_df6['age_40-49_2015'] = cities_df6['age40-44'].astype(float) + cities_df6['age45-49'].astype(float)
cities_df7['age_40-49_2016'] = cities_df7['age40-44'].astype(float) + cities_df7['age45-49'].astype(float)
cities_df8['age_40-49_2017'] = cities_df8['age40-44'].astype(float) + cities_df8['age45-49'].astype(float)
cities_df9['age_40-49_2018'] = cities_df9['age40-44'].astype(float) + cities_df9['age45-49'].astype(float)
# 50 - 59 
cities_df1['age_50-59_2010'] = cities_df1['age50-54'].astype(float) + cities_df1['age55-59'].astype(float)
cities_df2['age_50-59_2011'] = cities_df2['age50-54'].astype(float) + cities_df2['age55-59'].astype(float)
cities_df3['age_50-59_2012'] = cities_df3['age50-54'].astype(float) + cities_df3['age55-59'].astype(float)
cities_df4['age_50-59_2013'] = cities_df4['age50-54'].astype(float) + cities_df4['age55-59'].astype(float)
cities_df5['age_50-59_2014'] = cities_df5['age50-54'].astype(float) + cities_df5['age55-59'].astype(float)
cities_df6['age_50-59_2015'] = cities_df6['age50-54'].astype(float) + cities_df6['age55-59'].astype(float)
cities_df7['age_50-59_2016'] = cities_df7['age50-54'].astype(float) + cities_df7['age55-59'].astype(float)
cities_df8['age_50-59_2017'] = cities_df8['age50-54'].astype(float) + cities_df8['age55-59'].astype(float)
cities_df9['age_50-59_2018'] = cities_df9['age50-54'].astype(float) + cities_df9['age55-59'].astype(float)
# 60 and above
cities_df1['age_above_60_2010'] = cities_df1['age60-64'].astype(float) + cities_df1['age65-69'].astype(float) + cities_df1['age70-74'].astype(float) + cities_df1['age75-79'].astype(float) + cities_df1['age80-84'].astype(float) + cities_df1['age>85'].astype(float)
cities_df2['age_above_60_2011'] = cities_df2['age60-64'].astype(float) + cities_df2['age65-69'].astype(float) + cities_df2['age70-74'].astype(float) + cities_df2['age75-79'].astype(float) + cities_df2['age80-84'].astype(float) + cities_df2['age>85'].astype(float)
cities_df3['age_above_60_2012'] = cities_df3['age60-64'].astype(float) + cities_df3['age65-69'].astype(float) + cities_df3['age70-74'].astype(float) + cities_df3['age75-79'].astype(float) + cities_df3['age80-84'].astype(float) + cities_df3['age>85'].astype(float)
cities_df4['age_above_60_2013'] = cities_df4['age60-64'].astype(float) + cities_df4['age65-69'].astype(float) + cities_df4['age70-74'].astype(float) + cities_df4['age75-79'].astype(float) + cities_df4['age80-84'].astype(float) + cities_df4['age>85'].astype(float)
cities_df5['age_above_60_2014'] = cities_df5['age60-64'].astype(float) + cities_df5['age65-69'].astype(float) + cities_df5['age70-74'].astype(float) + cities_df5['age75-79'].astype(float) + cities_df5['age80-84'].astype(float) + cities_df5['age>85'].astype(float)
cities_df6['age_above_60_2015'] = cities_df6['age60-64'].astype(float) + cities_df6['age65-69'].astype(float) + cities_df6['age70-74'].astype(float) + cities_df6['age75-79'].astype(float) + cities_df6['age80-84'].astype(float) + cities_df6['age>85'].astype(float)
cities_df7['age_above_60_2016'] = cities_df7['age60-64'].astype(float) + cities_df7['age65-69'].astype(float) + cities_df7['age70-74'].astype(float) + cities_df7['age75-79'].astype(float) + cities_df7['age80-84'].astype(float) + cities_df7['age>85'].astype(float)
cities_df8['age_above_60_2017'] = cities_df8['age60-64'].astype(float) + cities_df8['age65-69'].astype(float) + cities_df8['age70-74'].astype(float) + cities_df8['age75-79'].astype(float) + cities_df8['age80-84'].astype(float) + cities_df8['age>85'].astype(float)
cities_df9['age_above_60_2018'] = cities_df9['age60-64'].astype(float) + cities_df9['age65-69'].astype(float) + cities_df9['age70-74'].astype(float) + cities_df9['age75-79'].astype(float) + cities_df9['age80-84'].astype(float) + cities_df9['age>85'].astype(float)

# %%
# Now we can drop the old columns with redundant information
cities_df1 = cities_df1.drop(['geo_id', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79','age80-84', 'age>85'], axis=1)
cities_df2 = cities_df2.drop(['geo_id', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79','age80-84', 'age>85'], axis=1)
cities_df3 = cities_df3.drop(['geo_id', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79','age80-84', 'age>85'], axis=1)
cities_df4 = cities_df4.drop(['geo_id', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79','age80-84', 'age>85'], axis=1)
cities_df5 = cities_df5.drop(['geo_id', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79','age80-84', 'age>85'], axis=1)
cities_df6 = cities_df6.drop(['geo_id', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79','age80-84', 'age>85'], axis=1)
cities_df7 = cities_df7.drop(['geo_id', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79','age80-84', 'age>85'], axis=1)
cities_df8 = cities_df8.drop(['geo_id', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79','age80-84', 'age>85'], axis=1)
cities_df9 = cities_df9.drop(['geo_id', 'age<5', 'age5-9', 'age10-14', 'age15-19', 'age20-24', 'age25-29', 'age30-34', 'age35-39', 'age40-44', 'age45-49', 'age50-54', 'age55-59', 'age60-64', 'age65-69', 'age70-74', 'age75-79','age80-84', 'age>85'], axis=1)

# %%
# For convenience, lets split the city_name column into 2 seperate columns
# one for city and one for state
cities_df1[['city','state']] = cities_df1['city'].str.split(',',expand=True)
cities_df2[['city','state']] = cities_df2['city'].str.split(',',expand=True)
cities_df3[['city','state']] = cities_df3['city'].str.split(',',expand=True)
cities_df4[['city','state']] = cities_df4['city'].str.split(',',expand=True)
cities_df5[['city','state']] = cities_df5['city'].str.split(',',expand=True)
cities_df6[['city','state']] = cities_df6['city'].str.split(',',expand=True)
cities_df7[['city','state']] = cities_df7['city'].str.split(',',expand=True)
cities_df8[['city','state']] = cities_df8['city'].str.split(',',expand=True)
cities_df9[['city','state']] = cities_df9['city'].str.split(',',expand=True)

# %%
# Create a new id column
cities_df1.insert(0, 'city_id', range(0, 0 + len(cities_df1)))
cities_df2.insert(0, 'city_id', range(0, 0 + len(cities_df2)))
cities_df3.insert(0, 'city_id', range(0, 0 + len(cities_df3)))
cities_df4.insert(0, 'city_id', range(0, 0 + len(cities_df4)))
cities_df5.insert(0, 'city_id', range(0, 0 + len(cities_df5)))
cities_df6.insert(0, 'city_id', range(0, 0 + len(cities_df6)))
cities_df7.insert(0, 'city_id', range(0, 0 + len(cities_df7)))
cities_df8.insert(0, 'city_id', range(0, 0 + len(cities_df8)))
cities_df9.insert(0, 'city_id', range(0, 0 + len(cities_df9)))

# %%
# pd.set_option('display.max_rows', None)
cities_df2
# Out:
#      city_id                city total_pop male_pop female_pop  \
# 1          0         Peoria city    113715    52652      61063
# 2          1       Rockford city    152485    74330      78155
# 3          2  Schaumburg village     74198    37038      37160
# 4          3      Skokie village     65070    30026      35044
# 5          4    Springfield city    117178    56687      60491
# ..       ...                 ...       ...      ...        ...
# 556      550          Elgin city    116108    55929      60179
# 557      551       Evanston city     74791    37222      37569
# 558      552         Joliet city    152902    74804      78098
# 559      553     Naperville city    143289    69689      73600
# 560      554    Palatine village     68815    33354      35461
#
#      age_under_20_2011  age_21-29_2011  age_30-39_2011  age_40-49_2011  \
# 1                 29.0            16.9            11.9            10.2
# ...

# %%
# Keep the city column uniform

#df1
cities_df1["city"] = cities_df1["city"].str.replace("city", "")
cities_df1["city"] = cities_df1["city"].str.replace("CDP", "")
cities_df1["city"] = cities_df1["city"].str.replace("town", "")
cities_df1["city"] = cities_df1["city"].str.replace("village", "")
cities_df1["city"] = cities_df1["city"].str.replace("urban county", "")
cities_df1["city"] = cities_df1["city"].str.replace("municipality", "")
cities_df1[['city','tbd']] = cities_df1['city'].str.split('-',expand=True)
cities_df1[['city','tbd1']] = cities_df1['city'].str.split('/',expand=True)
cities_df1[['city','tbd2']] = cities_df1['city'].str.split('(',expand=True)
cities_df1.city = cities_df1.city.str.rstrip()

#df2 
cities_df2["city"] = cities_df2["city"].str.replace("city", "")
cities_df2["city"] = cities_df2["city"].str.replace("CDP", "")
cities_df2["city"] = cities_df2["city"].str.replace("town", "")
cities_df2["city"] = cities_df2["city"].str.replace("village", "")
cities_df2["city"] = cities_df2["city"].str.replace("urban county", "")
cities_df2["city"] = cities_df2["city"].str.replace("municipality", "")
cities_df2[['city','tbd']] = cities_df2['city'].str.split('-',expand=True)
cities_df2[['city','tbd1']] = cities_df2['city'].str.split('/',expand=True)
cities_df2[['city','tbd2']] = cities_df2['city'].str.split('(',expand=True)
cities_df2.city = cities_df2.city.str.rstrip()

#df3
cities_df3["city"] = cities_df3["city"].str.replace("city", "")
cities_df3["city"] = cities_df3["city"].str.replace("CDP", "")
cities_df3["city"] = cities_df3["city"].str.replace("town", "")
cities_df3["city"] = cities_df3["city"].str.replace("village", "")
cities_df3["city"] = cities_df3["city"].str.replace("urban county", "")
cities_df3["city"] = cities_df3["city"].str.replace("municipality", "")
cities_df3[['city','tbd']] = cities_df3['city'].str.split('-',expand=True)
cities_df3[['city','tbd1']] = cities_df3['city'].str.split('/',expand=True)
cities_df3[['city','tbd2']] = cities_df3['city'].str.split('(',expand=True)
cities_df3.city = cities_df3.city.str.rstrip()

#df4
cities_df4["city"] = cities_df4["city"].str.replace("city", "")
cities_df4["city"] = cities_df4["city"].str.replace("CDP", "")
cities_df4["city"] = cities_df4["city"].str.replace("town", "")
cities_df4["city"] = cities_df4["city"].str.replace("village", "")
cities_df4["city"] = cities_df4["city"].str.replace("urban county", "")
cities_df4["city"] = cities_df4["city"].str.replace("municipality", "")
cities_df4[['city','tbd']] = cities_df4['city'].str.split('-',expand=True)
cities_df4[['city','tbd1']] = cities_df4['city'].str.split('/',expand=True)
cities_df4[['city','tbd2']] = cities_df4['city'].str.split('(',expand=True)
cities_df4.city = cities_df4.city.str.rstrip()

#df5
cities_df5["city"] = cities_df5["city"].str.replace("city", "")
cities_df5["city"] = cities_df5["city"].str.replace("CDP", "")
cities_df5["city"] = cities_df5["city"].str.replace("town", "")
cities_df5["city"] = cities_df5["city"].str.replace("village", "")
cities_df5["city"] = cities_df5["city"].str.replace("urban county", "")
cities_df5["city"] = cities_df5["city"].str.replace("municipality", "")
cities_df5[['city','tbd']] = cities_df5['city'].str.split('-',expand=True)
cities_df5[['city','tbd1']] = cities_df5['city'].str.split('/',expand=True)
cities_df5[['city','tbd2']] = cities_df5['city'].str.split('(',expand=True)
cities_df5.city = cities_df5.city.str.rstrip()

#df6
cities_df6["city"] = cities_df6["city"].str.replace("city", "")
cities_df6["city"] = cities_df6["city"].str.replace("CDP", "")
cities_df6["city"] = cities_df6["city"].str.replace("town", "")
cities_df6["city"] = cities_df6["city"].str.replace("village", "")
cities_df6["city"] = cities_df6["city"].str.replace("urban county", "")
cities_df6["city"] = cities_df6["city"].str.replace("municipality", "")
cities_df6[['city','tbd']] = cities_df6['city'].str.split('-',expand=True)
cities_df6[['city','tbd1']] = cities_df6['city'].str.split('/',expand=True)
cities_df6[['city','tbd2']] = cities_df6['city'].str.split('(',expand=True)
cities_df6.city = cities_df6.city.str.rstrip()

#df7
cities_df7["city"] = cities_df7["city"].str.replace("city", "")
cities_df7["city"] = cities_df7["city"].str.replace("CDP", "")
cities_df7["city"] = cities_df7["city"].str.replace("town", "")
cities_df7["city"] = cities_df7["city"].str.replace("village", "")
cities_df7["city"] = cities_df7["city"].str.replace("urban county", "")
cities_df7["city"] = cities_df7["city"].str.replace("municipality", "")
cities_df7[['city','tbd']] = cities_df7['city'].str.split('-',expand=True)
cities_df7[['city','tbd1']] = cities_df7['city'].str.split('/',expand=True)
cities_df7[['city','tbd2']] = cities_df7['city'].str.split('(',expand=True)
cities_df7.city = cities_df7.city.str.rstrip()

#df8
cities_df8["city"] = cities_df8["city"].str.replace("city", "")
cities_df8["city"] = cities_df8["city"].str.replace("CDP", "")
cities_df8["city"] = cities_df8["city"].str.replace("town", "")
cities_df8["city"] = cities_df8["city"].str.replace("village", "")
cities_df8["city"] = cities_df8["city"].str.replace("urban county", "")
cities_df8["city"] = cities_df8["city"].str.replace("municipality", "")
cities_df8[['city','tbd']] = cities_df8['city'].str.split('-',expand=True)
cities_df8[['city','tbd1']] = cities_df8['city'].str.split('/',expand=True)
cities_df8[['city','tbd2']] = cities_df8['city'].str.split('(',expand=True)
cities_df8.city = cities_df8.city.str.rstrip()

#df9
cities_df9["city"] = cities_df9["city"].str.replace("city", "")
cities_df9["city"] = cities_df9["city"].str.replace("CDP", "")
cities_df9["city"] = cities_df9["city"].str.replace("town", "")
cities_df9["city"] = cities_df9["city"].str.replace("village", "")
cities_df9["city"] = cities_df9["city"].str.replace("urban county", "")
cities_df9["city"] = cities_df9["city"].str.replace("municipality", "")
cities_df9[['city','tbd']] = cities_df9['city'].str.split('-',expand=True)
cities_df9[['city','tbd1']] = cities_df9['city'].str.split('/',expand=True)
cities_df9[['city','tbd2']] = cities_df9['city'].str.split('(',expand=True)
cities_df9.city = cities_df9.city.str.rstrip()
cities_df1
# Out:
#      city_id        city total_pop male_pop female_pop  age_under_20_2010  \
# 1          0  Birmingham    211670    98760     112910               23.4
# 2          1      Dothan     66121    31087      35034               28.1
# 3          2      Hoover     80376    38694      41682               30.1
# 4          3  Huntsville    181126    88132      92994               25.1
# 5          4      Mobile    195249    91746     103503               26.7
# ..       ...         ...       ...      ...        ...                ...
# 544      543     Madison    233777   115744     118033               23.1
# 545      544   Milwaukee    595587   286670     308917               30.6
# 546      545     Oshkosh     66110    34790      31320               25.7
# 547      546      Racine     78906    38342      40564               31.7
# 548      547    Waukesha     70741    34332      36409               26.3
#
#      age_21-29_2010  age_30-39_2010  age_40-49_2010  age_50-59_2010  \
# ...

# %%
# Drop columns made during the split
cities_df1 = cities_df1.drop(['tbd', 'tbd1', 'tbd2'], axis=1)
cities_df2 = cities_df2.drop(['tbd', 'tbd1', 'tbd2'], axis=1)
cities_df3 = cities_df3.drop(['tbd', 'tbd1', 'tbd2'], axis=1)
cities_df4 = cities_df4.drop(['tbd', 'tbd1', 'tbd2'], axis=1)
cities_df5 = cities_df5.drop(['tbd', 'tbd1', 'tbd2'], axis=1)
cities_df6 = cities_df6.drop(['tbd', 'tbd1', 'tbd2'], axis=1)
cities_df7 = cities_df7.drop(['tbd', 'tbd1', 'tbd2'], axis=1)
cities_df8 = cities_df8.drop(['tbd', 'tbd1', 'tbd2'], axis=1)
cities_df9 = cities_df9.drop(['tbd', 'tbd1', 'tbd2'], axis=1)

# Re-arrange columns aesthetically 
cities_df1 = cities_df1[["city_id", "city", "state", "total_pop", "male_pop", "female_pop", "age_under_20_2010", "age_21-29_2010", "age_30-39_2010", "age_40-49_2010", "age_50-59_2010", "age_above_60_2010"]]
cities_df2 = cities_df2[["city_id", "city", "state", "total_pop", "male_pop", "female_pop", "age_under_20_2011", "age_21-29_2011", "age_30-39_2011", "age_40-49_2011", "age_50-59_2011", "age_above_60_2011"]]
cities_df3 = cities_df3[["city_id", "city", "state", "total_pop", "male_pop", "female_pop", "age_under_20_2012", "age_21-29_2012", "age_30-39_2012", "age_40-49_2012", "age_50-59_2012", "age_above_60_2012"]]
cities_df4 = cities_df4[["city_id", "city", "state", "total_pop", "male_pop", "female_pop", "age_under_20_2013", "age_21-29_2013", "age_30-39_2013", "age_40-49_2013", "age_50-59_2013", "age_above_60_2013"]]
cities_df5 = cities_df5[["city_id", "city", "state", "total_pop", "male_pop", "female_pop", "age_under_20_2014", "age_21-29_2014", "age_30-39_2014", "age_40-49_2014", "age_50-59_2014", "age_above_60_2014"]]
cities_df6 = cities_df6[["city_id", "city", "state", "total_pop", "male_pop", "female_pop", "age_under_20_2015", "age_21-29_2015", "age_30-39_2015", "age_40-49_2015", "age_50-59_2015", "age_above_60_2015"]]
cities_df7 = cities_df7[["city_id", "city", "state", "total_pop", "male_pop", "female_pop", "age_under_20_2016", "age_21-29_2016", "age_30-39_2016", "age_40-49_2016", "age_50-59_2016", "age_above_60_2016"]]
cities_df8 = cities_df8[["city_id", "city", "state", "total_pop", "male_pop", "female_pop", "age_under_20_2017", "age_21-29_2017", "age_30-39_2017", "age_40-49_2017", "age_50-59_2017", "age_above_60_2017"]]
cities_df9 = cities_df9[["city_id", "city", "state", "total_pop", "male_pop", "female_pop", "age_under_20_2018", "age_21-29_2018", "age_30-39_2018", "age_40-49_2018", "age_50-59_2018", "age_above_60_2018"]]

# %%
cities_df9
# Out:
#      city_id        city       state total_pop male_pop female_pop  \
# 1          0  Birmingham     Alabama    212653    98257     114396
# 2          1      Dothan     Alabama     69400    32542      36858
# 3          2      Hoover     Alabama     84352    40334      44018
# 4          3  Huntsville     Alabama    187592    90041      97551
# 5          4      Mobile     Alabama    194670    92585     102085
# ..       ...         ...         ...       ...      ...        ...
# 580      578     Madison   Wisconsin    245674   119983     125691
# 581      579   Milwaukee   Wisconsin    599653   290147     309506
# 582      580     Oshkosh   Wisconsin     66631    34756      31875
# 583      581      Racine   Wisconsin     78054    37436      40618
# 584      582    Waukesha   Wisconsin     71482    34389      37093
#
#      age_under_20_2018  age_21-29_2018  age_30-39_2018  age_40-49_2018  \
# 1                 23.4            19.3            13.3            11.0
# ...

# %%
cities_df1
# Out:
#      city_id        city       state total_pop male_pop female_pop  \
# 1          0  Birmingham     Alabama    211670    98760     112910
# 2          1      Dothan     Alabama     66121    31087      35034
# 3          2      Hoover     Alabama     80376    38694      41682
# 4          3  Huntsville     Alabama    181126    88132      92994
# 5          4      Mobile     Alabama    195249    91746     103503
# ..       ...         ...         ...       ...      ...        ...
# 544      543     Madison   Wisconsin    233777   115744     118033
# 545      544   Milwaukee   Wisconsin    595587   286670     308917
# 546      545     Oshkosh   Wisconsin     66110    34790      31320
# 547      546      Racine   Wisconsin     78906    38342      40564
# 548      547    Waukesha   Wisconsin     70741    34332      36409
#
#      age_under_20_2010  age_21-29_2010  age_30-39_2010  age_40-49_2010  \
# 1                 23.4            17.0            13.4            13.5
# ...

# %%
cities_df1.city.unique()
# Out:
# array(['Birmingham', 'Dothan', 'Hoover', 'Huntsville', 'Mobile',
#        'Montgomery', 'Tuscaloosa', 'Anchorage', 'Avondale', 'Chandler',
#        'Flagstaff', 'Gilbert', 'Glendale', 'Goodyear', 'Mesa', 'Peoria',
#        'Phoenix', 'San Tan Valley', 'Scottsdale', 'Surprise', 'Tempe',
#        'Tucson', 'Yuma', 'Fayetteville', 'Fort Smith', 'Jonesboro',
#        'Little Rock', 'Springdale', 'Alameda', 'Alhambra', 'Anaheim',
#        'Antioch', 'Apple Valley', 'Arden', 'Bakersfield', 'Baldwin Park',
#        'Bellflower', 'Berkeley', 'Buena Park', 'Burbank', 'Camarillo',
#        'Carlsbad', 'Carson', 'Chico', 'Chino', 'Chino Hills',
#        'Chula Vista', 'Citrus Heights', 'Clovis', 'Compton', 'Concord',
#        'Corona', 'Costa Mesa', 'Daly City', 'Davis', 'Downey',
#        'East Los Angeles', 'El Cajon', 'Elk Grove', 'El Monte',
#        'Escondido', 'Fairfield', 'Folsom', 'Fontana', 'Fremont', 'Fresno',
#        'Fullerton', 'Garden Grove', 'Hawthorne', 'Hayward', 'Hemet',
# ...

# %%
cities_df9.city.unique()
# Out:
# array(['Birmingham', 'Dothan', 'Hoover', 'Huntsville', 'Mobile',
#        'Montgomery', 'Tuscaloosa', 'Anchorage', 'Avondale',
#        'Casas Adobes', 'Chandler', 'Flagstaff', 'Gilbert', 'Glendale',
#        'Goodyear', 'Mesa', 'Peoria', 'Phoenix', 'San Tan Valley',
#        'Scottsdale', 'Surprise', 'Tempe', 'Tucson', 'Yuma',
#        'Fayetteville', 'Fort Smith', 'Jonesboro', 'Little Rock',
#        'North Little Rock', 'Springdale', 'Alameda', 'Alhambra',
#        'Anaheim', 'Antioch', 'Apple Valley', 'Arden', 'Bakersfield',
#        'Baldwin Park', 'Bellflower', 'Berkeley', 'Buena Park', 'Burbank',
#        'Camarillo', 'Carlsbad', 'Carmichael', 'Carson', 'Chico', 'Chino',
#        'Chino Hills', 'Chula Vista', 'Citrus Heights', 'Clovis',
#        'Compton', 'Concord', 'Corona', 'Costa Mesa', 'Daly City', 'Davis',
#        'Downey', 'East Los Angeles', 'El Cajon', 'Elk Grove', 'El Monte',
#        'Escondido', 'Fairfield', 'Folsom', 'Fontana', 'Fremont', 'Fresno',
# ...

# %%
set(cities_df1.city).symmetric_difference(cities_df9.city)
# Out:
# {'Bayonne',
#  'Bethesda',
#  'Bismarck',
#  'Bossier City',
#  'Brentwood',
#  'Carmichael',
#  'Casas Adobes',
#  'Conroe',
#  'Delray Beach',
#  'Eagan',
#  'Franklin',
#  'Gaithersburg',
#  'Glen Burnie',
#  'Homestead',
#  'Johnson City',
#  'Jurupa Valley',
#  'Kirkland',
#  'Kissimmee',
#  'Laguna Niguel',
#  'Maple Grove',
#  'Marysville',
#  'Millcreek',
#  'New Braunfels',
#  'North Little Rock',
#  'Palo Alto',
#  'Pasco',
#  'Pine Hills',
#  'Rancho Cordova',
#  'Rockville',
#  'San Clemente',
#  'South San Francisco',
#  'Victoria',
#  'Walnut Creek',
#  'Woodbury',
#  'Yuba City'}
